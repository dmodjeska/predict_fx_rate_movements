# %% [markdown]
# CSCI E-82 - Advanced Machine Learning, Data Mining and Artificial Intelligence
# =====
#
# # Project - GAM Notebook
#
# ### *Dominic Murphy and David Modjeska*
#
# ------

# %% [markdown]
# # Introduction

# %%
import math
import numpy as np
import pandas as pd
import re

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.decomposition import PCA
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.utils import shuffle

from pygam import GAM            ##pip install pygam; pip install --user scikit-sparse
from pygam import LinearGAM  
from pygam.utils import generate_X_grid

# %matplotlib inline
from IPython.display import Image, display, HTML, clear_output

# %%
def my_display(str): 
    display(HTML(str))
    
def my_display_df(df): 
    display(HTML(df.to_html(index=False)))
    
def my_linespace():
    my_display('<p>')
    
plt.rcParams["patch.force_edgecolor"] = True   
plt.style.use('ggplot')

palette = sns.color_palette(palette = 'deep')
sns.set_palette(palette)

# %%
# suppress warnings for submission only

HTML('''<style>
div.output_stderr {display: none}
''')
# Out:
# <style>
# div.output_stderr {display: none}

# %% [markdown]
# # Modeling

# %% [markdown]
# *Note: some code has been adapted from https://machinelearningmastery.com/multivariate-time-series-forecasting-lstms-keras/*

# %% [markdown]
# #### Helper function to convert a dataframe for supervised learning

# %%
def series_to_supervised(data, n_in = 1, n_out = 1, drop_nan = True):
    columns = data.columns.values
    
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [(columns[j] + '(t-%d)' % (i)) for j in range(n_vars)]
    
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [(columns[j] + '(t)' % ()) for j in range(n_vars)]
        else:
            names += [(columns[j] + '(t+%d)' % (i)) for j in range(n_vars)]
    
    # put it all together
    agg = pd.concat(cols, axis = 1)
    agg.columns = names
    
    # drop rows with NaN values
    if drop_nan:
        agg.dropna(inplace = True)
    
    return agg

# %% [markdown]
# #### Load data

# %%
data = pd.read_csv('source_data.csv', parse_dates = ['date_key'])
print(data.shape)
# Out:
# (6551, 151)

# %% [markdown]
# #### Display first few rows of data

# %%
data.head()
# Out:
#    date_dayofyear   date_key  date_month  date_qtr  AU_IS_WORK_DAY  \
# 0               3 2000-01-03           1         1               0
# 1               4 2000-01-04           1         1               1
# 2               5 2000-01-05           1         1               1
# 3               6 2000-01-06           1         1               1
# 4               7 2000-01-07           1         1               1
#
#    US_IS_WORK_DAY  CA_IS_WORK_DAY  UK_IS_WORK_DAY  IS_EURO   AU_FX  \
# 0               1               1               0        1  0.6591
# 1               1               1               0        1  0.6562
# 2               1               1               1        1  0.6550
# 3               1               1               1        1  0.6540
# 4               1               1               1        1  0.6548
#
#       ...      UK_FX_MA_090  UK_FX_MA_180  UK_FX_MA_365  temperature  \
# 0     ...          1.628023      1.617005      1.617082    -0.943863
# 1     ...          1.627812      1.617446      1.617025    -0.940453
# 2     ...          1.627695      1.617946      1.616983    -0.940453
# 3     ...          1.627645      1.618471      1.616963    -0.936941
# 4     ...          1.627491      1.618938      1.616933    -0.936941
#
#    AU_BMP_Ratio  CA_BMP_Ratio  UK_BMP_Ratio  CH_BMP_Ratio  JP_BMP_Ratio  \
# 0      0.680107      0.784969      1.231594      3.715825      1.151735
# 1      0.677115      0.782104      1.239163      3.658705      1.136206
# 2      0.675876      0.782104      1.242570      3.649538      1.128760
# 3      0.674845      0.779259      1.247112      3.652829      1.113523
# 4      0.675670      0.782805      1.240223      3.672339      1.113735
#
#    time_index
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
#
# [5 rows x 151 columns]

# %% [markdown]
# #### Extract feature columns

# %%
feature_data = data.drop(['date_key', 'time_index'], axis = 1)
feature_cols = feature_data.columns
n_feature_cols = feature_data.shape[1]

# %% [markdown]
# ## Helper functions

# %% [markdown]
# #### Calculate the latest start date among a set of features

# %%
euro_start_date = '2000-01-03'

def get_start_row_index(data, col_names):
    return(max([data[col].isnull().idxmin() for col in col_names]))

# %% [markdown]
# #### Reduce dimensionality of X by PCA

# %%
def pca_X(currency_name, X):
    
    # fit a PCA for exploration only
    n_pcs_total = int(np.round(X.shape[1] - 1))
    pca = PCA(n_components = n_pcs_total, svd_solver = 'full', random_state = 0)
    pca.fit(X)
    ratios = np.cumsum(pca.explained_variance_ratio_)
    
    # scree plot of variances explained
    plt.plot(1.0 - ratios)
    plt.title(currency_name + " - PCA cumulative variance explained")
    plt.xlabel("Number of components")
    plt.ylabel("% of variance not explained")
    plt.show()
    
    # computer number of components to use
    n_pcs_to_use = np.where(ratios >= 0.999)[0][0] + 1
    print('Cumulative variance explained by the first ' + str(n_pcs_to_use) + ' components: ' + 
          str(np.round(ratios[n_pcs_to_use], 4)))
    
    # fit a PCA and transform the data
    pca = PCA(n_components = n_pcs_to_use, svd_solver = 'arpack', random_state = 0)
    pca.fit(X)    
    X_pca = pd.DataFrame(pca.transform(X))
    
    return(X_pca, pca)

# %% [markdown]
# #### Helper function to manage data reduction by PCA

# %%
def do_pca_X(currency_name, do_pca, n_past_lags, this_data_reframed):
    if do_pca and (n_past_lags > 1):
        X = this_data_reframed.iloc[:, :-1]        
        X_pca, pca = pca_X(currency_name, X)
        this_data_pca = X_pca        
        this_data_pca['y'] = this_data_reframed.iloc[:, -1].values 

        my_display("<h4>Shape of train and test data after PCA</h4>")
        print('Reduced data shape: ' + str(this_data_pca.shape))
    else:
        this_data_pca = this_data_reframed
        pca = None
        
    return(this_data_pca, pca)

# %% [markdown]
# #### Helper function to reframe data for supervised training

# %%
def reframe_data(this_data_scaled, n_past_lags, n_future_lags, n_these_cols):
    this_data_reframed = series_to_supervised(this_data_scaled, n_past_lags, n_future_lags) # X, y, and extra
    this_data_reframed_past = this_data_reframed.iloc[:, :(n_past_lags*n_these_cols)] # X = past = predictor
    this_data_reframed_future = this_data_reframed.iloc[:, -n_these_cols] # y = future = response
    this_data_reframed = pd.concat([this_data_reframed_past, this_data_reframed_future], axis = 1) # X and y
    
    print('Reframed data shape: ' + str(this_data_reframed.shape))
    return(this_data_reframed)

# %% [markdown]
# #### Prepare data for one model

# %%
n_past_lags = 7
n_future_lags = 7

def prep_model_data(currency_name, col_names, do_pca = False, verbose = 2):
    my_display("<h3>Prepare model data</h3>")
    
    # extract untransformed data
    n_these_cols = len(col_names)
    start_row_index = get_start_row_index(data, col_names)
    this_data = data[col_names].iloc[start_row_index:, :]
    n_these_rows = this_data.shape[0]
    
    # print data's time period
    print("Time period: " + str(data.date_key.dt.date[0]) + ' - ' + 
          str(data.date_key.dt.date[n_these_rows - 1]))
    
    # list untransformed model features
    if not do_pca:
        my_display("<h4>Features in Model</h4>")
        print(*col_names, sep = ', ')
        print()
    
    # scale data
    scaler = MinMaxScaler(feature_range = (0, 1))
    this_data_scaled = pd.DataFrame(scaler.fit_transform(this_data))
    this_data_scaled.columns = col_names
    print('Scaled data shape: ' + str(this_data_scaled.shape))
    
    # reframe data for supervised training
    this_data_reframed = reframe_data(this_data_scaled, n_past_lags, n_future_lags, n_these_cols)

    # PCA X (if needed)
    this_data_pca, pca = do_pca_X(currency_name, do_pca, n_past_lags, this_data_reframed)
    
    # display first few rows of supervised data
    if (verbose == 2 and not do_pca):
        my_display("<h4>First few rows of supervised data</h4>")
        my_linespace()
        my_display_df(this_data_pca.head())
        my_linespace()

    # predict y naively as the previous day (and drop initial rows with resulting NaNs)
    yhat_naive = this_data_pca.iloc[:, -1].shift(n_future_lags)
    this_data_pca = this_data_pca.iloc[n_future_lags:, :]
    yhat_naive = yhat_naive.iloc[n_future_lags:, ]
        
    # split into train and test sets
    train, test, yhat_naive_train, yhat_naive_test = \
        train_test_split(this_data_pca, yhat_naive, test_size = 0.33, shuffle = True, random_state = 0)
    
    # split into input and outputs
    train_X, train_y = train.iloc[:, :-1], train.iloc[:, -1]
    test_X, test_y = test.iloc[:, :-1], test.iloc[:, -1]
    
    if verbose == 2:
        my_display("<h4>Shape of train and test data</h4>")
        print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
    
    return(train_X, test_X, train_y, test_y, scaler, pca, yhat_naive_test, n_these_cols)

# %% [markdown]
# #### Helper function to instantiate and fit one model, and plot the feature importances

# %%
#Gam Specific call in function
def define_fit_model(currency_name, train_X, train_y, do_pca = False, verbose = 2):
    my_display("<h3>Fit model</h3>")
    
    # fit model
    model = LinearGAM().gridsearch(train_X, train_y)  

    # plot feature importances
    if verbose == 2 and not do_pca  :
        plot_splines(model, train_X, feature_col_names = train_X.columns[-5:], currency_name = currency_name)
                
    return(model)

# %%
#Gam Specific Funciton
#plots splines
def plot_splines(model, train_X, feature_col_names, currency_name):
    my_display("<h3>Feature Splines</h3>")
               
    XX = generate_X_grid(model)
    plt.rcParams['figure.figsize'] = (28, 8)
    fig, axs = plt.subplots(1, len(feature_col_names))
    titles = feature_col_names
    
    #last six
    for ax_i, i in enumerate(range(train_X.shape[1]-len(feature_col_names), train_X.shape[1],1)):
        if len(feature_col_names) == 1:
            ax = axs 
        else:    
            ax = axs[ax_i]   
        pdep, confi = model.partial_dependence(XX, feature=i+1, width=.95)
        ax.plot(XX[:, i], pdep)
        ax.plot(XX[:, i], confi[0][:, 0], c='grey', ls='--')
        ax.plot(XX[:, i], confi[0][:, 1], c='grey', ls='--')
        ax.set_title(currency_name + '- ' + titles[ax_i],fontsize=26)
    plt.show()

# %% [markdown]
# #### Helper function to inverse transform the data

# %%
def inverse_transform(y, X, scaler, pca, n_cols):
    if pca is not None:
        X = pca.inverse_transform(X)
    else:
        X = X.values
        
    inv_y = np.concatenate((y, X[:, 1:n_cols]), axis = 1)
    inv_y = scaler.inverse_transform(inv_y)
    inv_y = inv_y[:, 0]
    
    return(inv_y)

# %% [markdown]
# #### Helper function to plot histogram of prediction errors

# %%
def vis_error(currency_name, error):
    fig, ax = plt.subplots(figsize = (8.5, 4))
    sns.distplot(a = error, kde = False, bins = 40, hist_kws = {'alpha': 0.8}, ax = ax)
    ax.set_xlabel('Error')
    ax.set_ylabel('Frequency')
    ax.set_title(currency_name + ' - Distribution of test RMSE')
    plt.show()

# %% [markdown]
# #### Helper function to plot predicted vs. actual percentage change

# %%
def vis_percentage_pred(currency_name, y_pred_perc ,y_actual_perc, verbose=2):
    df = pd.DataFrame({'Predicted': y_pred_perc,'Actual'  : y_actual_perc})
    
    is_green = lambda a, b: (((a <= 0) and (b <=0)) or ((a > 0) and (b > 0))) * 1
    df['isGreen'] = df.Actual.combine(df.Predicted, func=is_green)
    
    fig, ax = plt.subplots(figsize = (21, 6))
    ax.scatter(df[df.isGreen==1].Predicted ,df[df.isGreen==1].Actual , edgecolors=(0, 0, 0), 
               alpha=.4, c='g', label='Profit') #cmap
    ax.scatter(df[df.isGreen==0].Predicted ,df[df.isGreen==0].Actual , edgecolors=(0, 0, 0), 
               alpha=.4, c='r', label='Loss')
    plt.axhline(y=0.0, color='grey', linestyle='-')
    plt.axvline(x=0.0, color='grey', linestyle='-')
    ax.set_xlabel('Predicted (% Change)')
    ax.set_ylabel('Actual  (% Change)') 
    ax.set_title(currency_name + ' - Predicted vs. Actual (% Change)')
    plt.legend()
    
    plt.show()

# %% [markdown]
# #### Score a model using RMSE with test data

# %%
no_score = None

def score_model(currency_name, best_model, test_X, test_y, scaler, pca, inv_yhat_naive, n_cols, verbose = 2):
    my_display("<h3>Score model on test data</h3>")
    
    # make a prediction on test data
    yhat = best_model.predict(test_X.values).reshape(-1, 1)

    # invert/reverse/undo scaling for forecast
    inv_yhat = inverse_transform(yhat, test_X, scaler, pca, n_cols)    
    
    # invert scaling for actual
    test_y = test_y.values.reshape((len(test_y), 1))
    inv_y = inverse_transform(test_y, test_X, scaler, pca, n_cols)
    
    # invert scaling for y-hat naive
    inv_yhat_naive = inv_yhat_naive.values.reshape((len(inv_yhat_naive), 1))  
    inv_yhat_naive = inverse_transform(inv_yhat_naive, test_X, scaler, pca, n_cols)    
    
    # naive model
    my_display("<h4>RMSE from naive model that always predicts the previous week's rate</h4>")
    naive_rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat_naive))
    print("RMSE: " + str(np.round(naive_rmse, 5)))
    
    # calculate RMSE on test data
    my_display("<h4>RMSE from fitted model</h4>")
    test_rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
    print("RMSE: " + str(np.round(test_rmse, 5)))

    # calculate relative prediction error percentages
    y_pred_perc   = 100 * (1 - (inv_yhat/inv_yhat_naive))
    y_actual_perc = 100 * (1 - (inv_y   /inv_yhat_naive))
    y_perc_error  = (np.abs(y_pred_perc - y_actual_perc)).mean()    
    
    # visualize relative prediction error percentages
    if verbose == 2 and pca is not None:
        vis_error(currency_name, inv_yhat)
        vis_percentage_pred(currency_name, y_pred_perc,y_actual_perc)    
    
    return(naive_rmse, test_rmse)

# %% [markdown]
# #### Top-level function to create, fit, and score one model

# %%
def do_one_model(currency_name, feature_col_names, do_pca = False, verbose = 2):
    
    train_X, test_X, train_y, test_y, scaler, pca, yhat_naive_test, n_features = \
        prep_model_data(currency_name, feature_col_names, do_pca, verbose)
    
    best_model = define_fit_model(currency_name, train_X, train_y, do_pca, verbose)

    naive_rmse, test_rmse = score_model(currency_name, best_model, test_X, test_y, scaler, pca, 
                                        yhat_naive_test, n_features, verbose = verbose)
    
    return(naive_rmse, test_rmse)

# %% [markdown]
# #### Create a dataframe to accumulate modeling results for all currencies

# %%
all_results = pd.DataFrame()

# %% [markdown]
# #### Accumulate results from one model

# %%
def accum_results(all_results, currency, naive_rmse, fx_rmse, fx_features_rmse, fx_all_rmse):
    results = pd.DataFrame({'Currency': currency, 
                              'Naive': naive_rmse, 
                              'FX Only': fx_rmse, 
                              'FX + Features': fx_features_rmse,
                              'All Features': fx_all_rmse},
                            index = range(1))
    all_results = all_results.append(results).reset_index(drop = True)
    return(all_results)

# %% [markdown]
# ## Australia

# %% [markdown]
# ### FX rates only

# %%
naive_rmse, fx_rmse = do_one_model
#       <td>0.006426</td>
#       <td>0.281865</td>
#       <td>0.015246</td>
#       <td>0.276118</td>
#       <td>0.140855</td>
#       <td>0.006426</td>
#       <td>0.282349</td>
#       <td>0.015581</td>
#       <td>0.276773</td>
#       <td>0.142860</td>
#       <td>0.006426</td>
#       <td>0.299935</td>
#       <td>0.015551</td>
#       <td>0.280208</td>
#       <td>0.148400</td>
#       <td>0.006426</td>
#       <td>0.296547</td>
#     </tr>
#   </tbody>
# </table>
# <p>
# <h4>Shape of train and test data</h4>
# (4375, 35) (4375,) (2156, 35) (2156,)
# <h3>Fit model</h3>
# N/A% (0 of 11) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#   9% (1 of 11) |##                        | Elapsed Time: 0:00:02 ETA:  0:00:20/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  18% (2 of 11) |####                      | Elapsed Time: 0:00:04 ETA:  0:00:18/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  27% (3 of 11) |#######                   | Elapsed Time: 0:00:06 ETA:  0:00:16/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  36% (4 of 11) |#########                 | Elapsed Time: 0:00:08 ETA:  0:00:14/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  45% (5 of 11) |###########               | Elapsed Time: 0:00:10 ETA:  0:00:12/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  54% (6 of 11) |##############            | Elapsed Time: 0:00:12 ETA:  0:00:10/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  63% (7 of 11) |################          | Elapsed Time: 0:00:14 ETA:  0:00:08/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  72% (8 of 11) |##################        | Elapsed Time: 0:00:16 ETA:  0:00:06/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  81% (9 of 11) |#####################     | Elapsed Time: 0:00:18 ETA:  0:00:04/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  90% (10 of 11) |######################   | Elapsed Time: 0:00:21 ETA:  0:00:02/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# 100% (11 of 11) |#########################| Elapsed Time: 0:00:23 Time: 0:00:23
# <h3>Feature Splines</h3>
# <h3>Score model on test data</h3>
# <h4>RMSE from naive model that always predicts the previous week's rate</h4>
# RMSE: 0.01386
# <h4>RMSE from fitted model</h4>
# RMSE: 0.0122

# %% [markdown]
# ### All features

# %%
cols = [feature_cols[i] for i in range(n_feature_cols) 
        if re.search('AU_FX', feature_cols[i]) == None]
naive_rmse, fx_all_rmse = do_one_model('AUD', feature_col_names = ['AU_FX'] + cols, do_pca = True)
# Out:
# <h3>Prepare model data</h3>
# Time period: 2000-01-03 - 2012-12-05
# Scaled data shape: (4721, 141)
# Reframed data shape: (4708, 988)
# Cumulative variance explained by the first 94 components: 0.9991
# <h4>Shape of train and test data after PCA</h4>
# Reduced data shape: (4708, 95)
# <h4>Shape of train and test data</h4>
# (3149, 94) (3149,) (1552, 94) (1552,)
# <h3>Fit model</h3>
# N/A% (0 of 11) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/pygam.py:597: RuntimeWarning: divide by zero encountered in log
#   return np.log(self.distribution.pdf(y=y, mu=mu, weights=weights)).sum()
#   9% (1 of 11) |##                        | Elapsed Time: 0:00:17 ETA:  0:02:57/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/pygam.py:597: RuntimeWarning: divide by zero encountered in log
#   return np.log(self.distribution.pdf(y=y, mu=mu, weights=weights)).sum()
#  18% (2 of 11) |####                      | Elapsed Time: 0:00:35 ETA:  0:02:40/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/pygam.py:597: RuntimeWarning: divide by zero encountered in log
#   return np.log(self.distribution.pdf(y=y, mu=mu, weights=weights)).sum()
#  27% (3 of 11) |#######                   | Elapsed Time: 0:00:53 ETA:  0:02:23/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/pygam.py:597: RuntimeWarning: divide by zero encountered in log
#   return np.log(self.distribution.pdf(y=y, mu=mu, weights=weights)).sum()
#  36% (4 of 11) |#########                 | Elapsed Time: 0:01:11 ETA:  0:02:05/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/pygam.py:597: RuntimeWarning: divide by zero encountered in log
#   return np.log(self.distribution.pdf(y=y, mu=mu, weights=weights)).sum()
#  45% (5 of 11) |###########               | Elapsed Time: 0:01:29 ETA:  0:01:47/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/pygam.py:597: RuntimeWarning: divide by zero encountered in log
#   return np.log(self.distribution.pdf(y=y, mu=mu, weights=weights)).sum()
#  54% (6 of 11) |##############            | Elapsed Time: 0:01:47 ETA:  0:01:29/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  63% (7 of 11) |################          | Elapsed Time: 0:02:05 ETA:  0:01:11/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  72% (8 of 11) |##################        | Elapsed Time: 0:02:23 ETA:  0:00:53/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  81% (9 of 11) |#####################     | Elapsed Time: 0:02:41 ETA:  0:00:35/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  90% (10 of 11) |######################   | Elapsed Time: 0:02:59 ETA:  0:00:17/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# 100% (11 of 11) |#########################| Elapsed Time: 0:03:18 Time: 0:03:18
# <h3>Score model on test data</h3>
# <h4>RMSE from naive model that always predicts the previous week's rate</h4>
# RMSE: 0.01553
# <h4>RMSE from fitted model</h4>
# RMSE: 0.0092

# %%
all_results = accum_results(all_results, 'AUD', naive_rmse, fx_rmse, fx_features_rmse, fx_all_rmse)

# %% [markdown]
# ## Canada

# %% [markdown]
# ### FX rates only

# %%
naive_rmse, fx_rmse = do_one_model('CAD', feature_col_names = ['CA_FX'], verbose = 0)
# Out:
# <h3>Prepare model data</h3>
# Time period: 2000-01-03 - 2017-12-09
# <h4>Features in Model</h4>
# CA_FX
#
# Scaled data shape: (6551, 1)
# Reframed data shape: (6538, 8)
# <h3>Fit model</h3>
# N/A% (0 of 11) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#   9% (1 of 11) |##                        | Elapsed Time: 0:00:00 ETA:  0:00:02/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  18% (2 of 11) |####                      | Elapsed Time: 0:00:00 ETA:  0:00:02/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  27% (3 of 11) |#######                   | Elapsed Time: 0:00:00 ETA:  0:00:02/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  36% (4 of 11) |#########                 | Elapsed Time: 0:00:01 ETA:  0:00:01/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  45% (5 of 11) |###########               | Elapsed Time: 0:00:01 ETA:  0:00:01/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  54% (6 of 11) |##############            | Elapsed Time: 0:00:01 ETA:  0:00:01/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  63% (7 of 11) |################          | Elapsed Time: 0:00:01 ETA:  0:00:01/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  72% (8 of 11) |##################        | Elapsed Time: 0:00:01 ETA:  0:00:00/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  81% (9 of 11) |#####################     | Elapsed Time: 0:00:02 ETA:  0:00:00/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  90% (10 of 11) |######################   | Elapsed Time: 0:00:02 ETA:  0:00:00/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# 100% (11 of 11) |#########################| Elapsed Time: 0:00:02 Time: 0:00:02
# <h3>Score model on test data</h3>
# <h4>RMSE from naive model that always predicts the previous week's rate</h4>
# RMSE: 0.01081
# <h4>RMSE from fitted model</h4>
# RMSE: 0.0106

# %% [markdown]
# ### FX rates and other features

# %%
naive_rmse, fx_features_rmse = do_one_model('CAD', feature_col_names =  ['CA_FX', 'CA_GDP', 'CA_CPI', 'US_GDP'])
# Out:
# <h3>Prepare model data</h3>
# Time period: 2000-01-03 - 2017-12-09
# <h4>Features in Model</h4>
# CA_FX, CA_GDP, CA_CPI, US_GDP
#
# Scaled data shape: (6551, 4)
# Reframed data shape: (6538, 29)
# <h4>First few rows of supervised data</h4>
# <p>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>CA_FX(t-7)</th>
#       <th>CA_GDP(t-7)</th>
#       <th>CA_CPI(t-7)</th>
#       <th>US_GDP(t-7)</th>
#       <th>CA_FX(t-6)</th>
#       <th>CA_GDP(t-6)</th>
#       <th>CA_CPI(t-6)</th>
#       <th>US_GDP(t-6)</th>
#       <th>CA_FX(t-5)</th>
#       <th>CA_GDP(t-5)</th>
#       <th>CA_CPI(t-5)</th>
#       <th>US_GDP(t-5)</th>
#       <th>CA_FX(t-4)</th>
#       <th>CA_GDP(t-4)</th>
#       <th>CA_CPI(t-4)</th>
#       <th>US_GDP(t-4)</th>
#       <th>CA_FX(t-3)</th>
#       <th>CA_GDP(t-3)</th>
#       <th>CA_CPI(t-3)</th>
#       <th>US_GDP(t-3)</th>
#       <th>CA_FX(t-2)</th>
#       <th>CA_GDP(t-2)</th>
#       <th>CA_CPI(t-2)</th>
#       <th>US_GDP(t-2)</th>
#       <th>CA_FX(t-1)</th>
#       <th>CA_GDP(t-1)</th>
#       <th>CA_CPI(t-1)</th>
#       <th>US_GDP(t-1)</th>
#       <th>CA_FX(t+6)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0
#       <td>0.991853</td>
#       <td>0.579493</td>
#       <td>0.639560</td>
#       <td>0.140855</td>
#       <td>0.990689</td>
#       <td>0.582373</td>
#       <td>0.643956</td>
#       <td>0.142860</td>
#       <td>0.989525</td>
#       <td>0.585253</td>
#       <td>0.648352</td>
#       <td>0.148400</td>
#       <td>0.988361</td>
#       <td>0.588134</td>
#       <td>0.652747</td>
#       <td>0.149513</td>
#     </tr>
#   </tbody>
# </table>
# <p>
# <h4>Shape of train and test data</h4>
# (4375, 28) (4375,) (2156, 28) (2156,)
# <h3>Fit model</h3>
# N/A% (0 of 11) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#   9% (1 of 11) |##                        | Elapsed Time: 0:00:01 ETA:  0:00:16/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  18% (2 of 11) |####                      | Elapsed Time: 0:00:03 ETA:  0:00:14/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  27% (3 of 11) |#######                   | Elapsed Time: 0:00:05 ETA:  0:00:13/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  36% (4 of 11) |#########                 | Elapsed Time: 0:00:06 ETA:  0:00:11/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  45% (5 of 11) |###########               | Elapsed Time: 0:00:08 ETA:  0:00:09/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  54% (6 of 11) |##############            | Elapsed Time: 0:00:09 ETA:  0:00:08/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  63% (7 of 11) |################          | Elapsed Time: 0:00:11 ETA:  0:00:06/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  72% (8 of 11) |##################        | Elapsed Time: 0:00:13 ETA:  0:00:04/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  81% (9 of 11) |#####################     | Elapsed Time: 0:00:14 ETA:  0:00:03/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  90% (10 of 11) |######################   | Elapsed Time: 0:00:16 ETA:  0:00:01/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# 100% (11 of 11) |#########################| Elapsed Time: 0:00:17 Time: 0:00:17
# <h3>Feature Splines</h3>
# <h3>Score model on test data</h3>
# <h4>RMSE from naive model that always predicts the previous week's rate</h4>
# RMSE: 0.01081
# <h4>RMSE from fitted model</h4>
# RMSE: 0.00935

# %% [markdown]
# ### All features

# %%
cols = [feature_cols[i] for i in range(n_feature_cols) 
        if re.search('CA_FX', feature_cols[i]) == None]
naive_rmse, fx_all_rmse = do_one_model('CAD', feature_col_names = ['CA_FX'] + cols, do_pca = True)
# Out:
# <h3>Prepare model data</h3>
# Time period: 2000-01-03 - 2012-12-05
# Scaled data shape: (4721, 139)
# Reframed data shape: (4708, 974)
# Cumulative variance explained by the first 93 components: 0.9991
# <h4>Shape of train and test data after PCA</h4>
# Reduced data shape: (4708, 94)
# <h4>Shape of train and test data</h4>
# (3149, 93) (3149,) (1552, 93) (1552,)
# <h3>Fit model</h3>
# N/A% (0 of 11) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/pygam.py:597: RuntimeWarning: divide by zero encountered in log
#   return np.log(self.distribution.pdf(y=y, mu=mu, weights=weights)).sum()
#   9% (1 of 11) |##                        | Elapsed Time: 0:00:17 ETA:  0:02:56/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/pygam.py:597: RuntimeWarning: divide by zero encountered in log
#   return np.log(self.distribution.pdf(y=y, mu=mu, weights=weights)).sum()
#  18% (2 of 11) |####                      | Elapsed Time: 0:00:35 ETA:  0:02:39/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/pygam.py:597: RuntimeWarning: divide by zero encountered in log
#   return np.log(self.distribution.pdf(y=y, mu=mu, weights=weights)).sum()
#  27% (3 of 11) |#######                   | Elapsed Time: 0:00:54 ETA:  0:02:24/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/pygam.py:597: RuntimeWarning: divide by zero encountered in log
#   return np.log(self.distribution.pdf(y=y, mu=mu, weights=weights)).sum()
#  36% (4 of 11) |#########                 | Elapsed Time: 0:01:11 ETA:  0:02:05/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/pygam.py:597: RuntimeWarning: divide by zero encountered in log
#   return np.log(self.distribution.pdf(y=y, mu=mu, weights=weights)).sum()
#  45% (5 of 11) |###########               | Elapsed Time: 0:01:30 ETA:  0:01:48/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/pygam.py:597: RuntimeWarning: divide by zero encountered in log
#   return np.log(self.distribution.pdf(y=y, mu=mu, weights=weights)).sum()
#  54% (6 of 11) |##############            | Elapsed Time: 0:01:48 ETA:  0:01:30/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  63% (7 of 11) |################          | Elapsed Time: 0:02:05 ETA:  0:01:11/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  72% (8 of 11) |##################        | Elapsed Time: 0:02:23 ETA:  0:00:53/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  81% (9 of 11) |#####################     | Elapsed Time: 0:02:41 ETA:  0:00:35/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  90% (10 of 11) |######################   | Elapsed Time: 0:02:59 ETA:  0:00:18/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# 100% (11 of 11) |#########################| Elapsed Time: 0:03:17 Time: 0:03:17
# <h3>Score model on test data</h3>
# <h4>RMSE from naive model that always predicts the previous week's rate</h4>
# RMSE: 0.01205
# <h4>RMSE from fitted model</h4>
# RMSE: 0.00721

# %%
all_results = accum_results(all_results, 'CAD', naive_rmse, fx_rmse, fx_features_rmse, fx_all_rmse)

# %% [markdown]
# ## EU

# %% [markdown]
# ### FX rates only

# %%
naive_rmse, fx_rmse = do_one_model('EUR', feature_col_names = ['EU_FX'], verbose = 0)
# Out:
# <h3>Prepare model data</h3>
# Time period: 2000-01-03 - 2017-12-09
# <h4>Features in Model</h4>
# EU_FX
#
# Scaled data shape: (6551, 1)
# Reframed data shape: (6538, 8)
# <h3>Fit model</h3>
# N/A% (0 of 11) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#   9% (1 of 11) |##                        | Elapsed Time: 0:00:00 ETA:  0:00:02/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  18% (2 of 11) |####                      | Elapsed Time: 0:00:00 ETA:  0:00:01/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  27% (3 of 11) |#######                   | Elapsed Time: 0:00:00 ETA:  0:00:01/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  36% (4 of 11) |#########                 | Elapsed Time: 0:00:00 ETA:  0:00:01/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  45% (5 of 11) |###########               | Elapsed Time: 0:00:01 ETA:  0:00:01/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  54% (6 of 11) |##############            | Elapsed Time: 0:00:01 ETA:  0:00:01/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  63% (7 of 11) |################          | Elapsed Time: 0:00:01 ETA:  0:00:00/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  72% (8 of 11) |##################        | Elapsed Time: 0:00:01 ETA:  0:00:00/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  81% (9 of 11) |#####################     | Elapsed Time: 0:00:01 ETA:  0:00:00/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  90% (10 of 11) |######################   | Elapsed Time: 0:00:02 ETA:  0:00:00/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# 100% (11 of 11) |#########################| Elapsed Time: 0:00:02 Time: 0:00:02
# <h3>Score model on test data</h3>
# <h4>RMSE from naive model that always predicts the previous week's rate</h4>
# RMSE: 0.0169
# <h4>RMSE from fitted model</h4>
# RMSE: 0.0168

# %% [markdown]
# ### FX rates and other features

# %%
naive_rmse, fx_features_rmse = do_one_model('EUR', feature_col_names = \
    ['EU_FX', 'CH_FX', 'DE_INT_TB', 'US_INT_TB'])
# Out:
# <h3>Prepare model data</h3>
# Time period: 2000-01-03 - 2017-12-09
# <h4>Features in Model</h4>
# EU_FX, CH_FX, DE_INT_TB, US_INT_TB
#
# Scaled data shape: (6551, 4)
# Reframed data shape: (6538, 29)
# <h4>First few rows of supervised data</h4>
# <p>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>EU_FX(t-7)</th>
#       <th>CH_FX(t-7)</th>
#       <th>DE_INT_TB(t-7)</th>
#       <th>US_INT_TB(t-7)</th>
#       <th>EU_FX(t-6)</th>
#       <th>CH_FX(t-6)</th>
#       <th>DE_INT_TB(t-6)</th>
#       <th>US_INT_TB(t-6)</th>
#       <th>EU_FX(t-5)</th>
#       <th>CH_FX(t-5)</th>
#       <th>DE_INT_TB(t-5)</th>
#       <th>US_INT_TB(t-5)</th>
#       <th>EU_FX(t-4)</th>
#       <th>CH_FX(t-4)</th>
#       <th>DE_INT_TB(t-4)</th>
#       <th>US_INT_TB(t-4)</th>
#       <th>EU_FX(t-3)</th>
#       <th>CH_FX(t-3)</th>
#       <th>DE_INT_TB(t-3)</th>
#       <th>US_INT_TB(t-3)</th>
#       <th>EU_FX(t-2)</th>
#       <th>CH_FX(t-2)</th>
#       <th>DE_INT_TB(t-2)</th>
#       <th>US_INT_TB(t-2)</th>
#       <th>EU_FX(t-1)</th>
#       <th>CH_FX(t-1)</th>
#       <th>DE_INT_TB(t-1)</th>
#       <th>US_INT_TB(t-1)</th>
#       <th>EU_FX(t+6)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0
#       <td>0.870444</td>
#       <td>0.257881</td>
#       <td>0.765109</td>
#       <td>0.641026</td>
#       <td>0.871649</td>
#       <td>0.256072</td>
#       <td>0.767573</td>
#       <td>0.641026</td>
#       <td>0.872853</td>
#       <td>0.265116</td>
#       <td>0.758536</td>
#       <td>0.641026</td>
#       <td>0.874057</td>
#       <td>0.259819</td>
#       <td>0.763557</td>
#       <td>0.641026</td>
#       <td>0.875262</td>
#       <td>0.258398</td>
#       <td>0.767847</td>
#       <td>0.641026</td>
#       <td>0.876466</td>
#       <td>0.240698</td>
#     </tr>
#   </tbody>
# </table>
# <p>
# <h4>Shape of train and test data</h4>
# (4375, 28) (4375,) (2156, 28) (2156,)
# <h3>Fit model</h3>
# N/A% (0 of 11) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#   9% (1 of 11) |##                        | Elapsed Time: 0:00:01 ETA:  0:00:14/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  18% (2 of 11) |####                      | Elapsed Time: 0:00:02 ETA:  0:00:13/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  27% (3 of 11) |#######                   | Elapsed Time: 0:00:04 ETA:  0:00:11/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  36% (4 of 11) |#########                 | Elapsed Time: 0:00:05 ETA:  0:00:10/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  45% (5 of 11) |###########               | Elapsed Time: 0:00:07 ETA:  0:00:08/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  54% (6 of 11) |##############            | Elapsed Time: 0:00:08 ETA:  0:00:07/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  63% (7 of 11) |################          | Elapsed Time: 0:00:10 ETA:  0:00:05/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  72% (8 of 11) |##################        | Elapsed Time: 0:00:11 ETA:  0:00:04/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  81% (9 of 11) |#####################     | Elapsed Time: 0:00:13 ETA:  0:00:02/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  90% (10 of 11) |######################   | Elapsed Time: 0:00:14 ETA:  0:00:01/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# 100% (11 of 11) |#########################| Elapsed Time: 0:00:16 Time: 0:00:16
# <h3>Feature Splines</h3>
# <h3>Score model on test data</h3>
# <h4>RMSE from naive model that always predicts the previous week's rate</h4>
# RMSE: 0.0169
# <h4>RMSE from fitted model</h4>
# RMSE: 0.01595

# %% [markdown]
# ### All features

# %%
cols = [feature_cols[i] for i in range(n_feature_cols) 
        if re.search('EU_FX', feature_cols[i]) == None]
naive_rmse, fx_all_rmse = do_one_model('EUR', feature_col_names = ['EU_FX'] + cols, do_pca = True)
# Out:
# <h3>Prepare model data</h3>
# Time period: 2000-01-03 - 2012-12-05
# Scaled data shape: (4721, 141)
# Reframed data shape: (4708, 988)
# Cumulative variance explained by the first 93 components: 0.999
# <h4>Shape of train and test data after PCA</h4>
# Reduced data shape: (4708, 94)
# <h4>Shape of train and test data</h4>
# (3149, 93) (3149,) (1552, 93) (1552,)
# <h3>Fit model</h3>
# N/A% (0 of 11) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/pygam.py:597: RuntimeWarning: divide by zero encountered in log
#   return np.log(self.distribution.pdf(y=y, mu=mu, weights=weights)).sum()
#   9% (1 of 11) |##                        | Elapsed Time: 0:00:17 ETA:  0:02:51/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/pygam.py:597: RuntimeWarning: divide by zero encountered in log
#   return np.log(self.distribution.pdf(y=y, mu=mu, weights=weights)).sum()
#  18% (2 of 11) |####                      | Elapsed Time: 0:00:34 ETA:  0:02:34/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/pygam.py:597: RuntimeWarning: divide by zero encountered in log
#   return np.log(self.distribution.pdf(y=y, mu=mu, weights=weights)).sum()
#  27% (3 of 11) |#######                   | Elapsed Time: 0:00:51 ETA:  0:02:17/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/pygam.py:597: RuntimeWarning: divide by zero encountered in log
#   return np.log(self.distribution.pdf(y=y, mu=mu, weights=weights)).sum()
#  36% (4 of 11) |#########                 | Elapsed Time: 0:01:09 ETA:  0:02:00/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/pygam.py:597: RuntimeWarning: divide by zero encountered in log
#   return np.log(self.distribution.pdf(y=y, mu=mu, weights=weights)).sum()
#  45% (5 of 11) |###########               | Elapsed Time: 0:01:26 ETA:  0:01:43/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/pygam.py:597: RuntimeWarning: divide by zero encountered in log
#   return np.log(self.distribution.pdf(y=y, mu=mu, weights=weights)).sum()
#  54% (6 of 11) |##############            | Elapsed Time: 0:01:44 ETA:  0:01:26/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  63% (7 of 11) |################          | Elapsed Time: 0:02:01 ETA:  0:01:09/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  72% (8 of 11) |##################        | Elapsed Time: 0:02:20 ETA:  0:00:52/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  81% (9 of 11) |#####################     | Elapsed Time: 0:02:38 ETA:  0:00:35/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  90% (10 of 11) |######################   | Elapsed Time: 0:02:56 ETA:  0:00:17/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# 100% (11 of 11) |#########################| Elapsed Time: 0:03:14 Time: 0:03:14
# <h3>Score model on test data</h3>
# <h4>RMSE from naive model that always predicts the previous week's rate</h4>
# RMSE: 0.01811
# <h4>RMSE from fitted model</h4>
# RMSE: 0.0116

# %%
all_results = accum_results(all_results, 'EUR', naive_rmse, fx_rmse, fx_features_rmse, fx_all_rmse)

# %% [markdown]
# ## Japan

# %% [markdown]
# ### FX rates only

# %%
naive_rmse, fx_rmse = do_one_model('JPY', feature_col_names = ['JP_FX'], verbose = 0)
# Out:
# <h3>Prepare model data</h3>
# Time period: 2000-01-03 - 2017-12-09
# <h4>Features in Model</h4>
# JP_FX
#
# Scaled data shape: (6551, 1)
# Reframed data shape: (6538, 8)
# <h3>Fit model</h3>
# N/A% (0 of 11) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#   9% (1 of 11) |##                        | Elapsed Time: 0:00:00 ETA:  0:00:02/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  18% (2 of 11) |####                      | Elapsed Time: 0:00:00 ETA:  0:00:01/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  27% (3 of 11) |#######                   | Elapsed Time: 0:00:00 ETA:  0:00:01/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  36% (4 of 11) |#########                 | Elapsed Time: 0:00:00 ETA:  0:00:01/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  45% (5 of 11) |###########               | Elapsed Time: 0:00:01 ETA:  0:00:01/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  54% (6 of 11) |##############            | Elapsed Time: 0:00:01 ETA:  0:00:01/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  63% (7 of 11) |################          | Elapsed Time: 0:00:01 ETA:  0:00:00/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  72% (8 of 11) |##################        | Elapsed Time: 0:00:01 ETA:  0:00:00/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  81% (9 of 11) |#####################     | Elapsed Time: 0:00:01 ETA:  0:00:00/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  90% (10 of 11) |######################   | Elapsed Time: 0:00:02 ETA:  0:00:00/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# 100% (11 of 11) |#########################| Elapsed Time: 0:00:02 Time: 0:00:02
# <h3>Score model on test data</h3>
# <h4>RMSE from naive model that always predicts the previous week's rate</h4>
# RMSE: 0.00013
# <h4>RMSE from fitted model</h4>
# RMSE: 0.00013

# %% [markdown]
# ### FX rates and other features

# %%
naive_rmse, fx_features_rmse = do_one_model('JPY', feature_col_names = ['JP_FX', 'JP_GDP', 'JP_UR', 'JP_CPI'])
# Out:
# <h3>Prepare model data</h3>
# Time period: 2000-01-03 - 2017-12-09
# <h4>Features in Model</h4>
# JP_FX, JP_GDP, JP_UR, JP_CPI
#
# Scaled data shape: (6551, 4)
# Reframed data shape: (6538, 29)
# <h4>First few rows of supervised data</h4>
# <p>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>JP_FX(t-7)</th>
#       <th>JP_GDP(t-7)</th>
#       <th>JP_UR(t-7)</th>
#       <th>JP_CPI(t-7)</th>
#       <th>JP_FX(t-6)</th>
#       <th>JP_GDP(t-6)</th>
#       <th>JP_UR(t-6)</th>
#       <th>JP_CPI(t-6)</th>
#       <th>JP_FX(t-5)</th>
#       <th>JP_GDP(t-5)</th>
#       <th>JP_UR(t-5)</th>
#       <th>JP_CPI(t-5)</th>
#       <th>JP_FX(t-4)</th>
#       <th>JP_GDP(t-4)</th>
#       <th>JP_UR(t-4)</th>
#       <th>JP_CPI(t-4)</th>
#       <th>JP_FX(t-3)</th>
#       <th>JP_GDP(t-3)</th>
#       <th>JP_UR(t-3)</th>
#       <th>JP_CPI(t-3)</th>
#       <th>JP_FX(t-2)</th>
#       <th>JP_GDP(t-2)</th>
#       <th>JP_UR(t-2)</th>
#       <th>JP_CPI(t-2)</th>
#       <th>JP_FX(t-1)</th>
#       <th>JP_GDP(t-1)</th>
#       <th>JP_UR(t-1)</th>
#       <th>JP_CPI(t-1)</th>
#       <th>JP_FX(t+6)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0
#       <td>0.268991</td>
#       <td>0.359758</td>
#       <td>0.925601</td>
#       <td>0.698554</td>
#       <td>0.270552</td>
#       <td>0.359186</td>
#       <td>0.922954</td>
#       <td>0.699666</td>
#       <td>0.272112</td>
#       <td>0.346653</td>
#       <td>0.920307</td>
#       <td>0.700779</td>
#       <td>0.273673</td>
#       <td>0.351736</td>
#       <td>0.917659</td>
#       <td>0.701891</td>
#       <td>0.275234</td>
#       <td>0.346653</td>
#       <td>0.915012</td>
#       <td>0.703003</td>
#       <td>0.276795</td>
#       <td>0.356540</td>
#     </tr>
#   </tbody>
# </table>
# <p>
# <h4>Shape of train and test data</h4>
# (4375, 28) (4375,) (2156, 28) (2156,)
# <h3>Fit model</h3>
# N/A% (0 of 11) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#   9% (1 of 11) |##                        | Elapsed Time: 0:00:01 ETA:  0:00:14/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  18% (2 of 11) |####                      | Elapsed Time: 0:00:02 ETA:  0:00:13/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  27% (3 of 11) |#######                   | Elapsed Time: 0:00:04 ETA:  0:00:11/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  36% (4 of 11) |#########                 | Elapsed Time: 0:00:06 ETA:  0:00:10/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  45% (5 of 11) |###########               | Elapsed Time: 0:00:07 ETA:  0:00:09/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  54% (6 of 11) |##############            | Elapsed Time: 0:00:09 ETA:  0:00:07/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  63% (7 of 11) |################          | Elapsed Time: 0:00:10 ETA:  0:00:06/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  72% (8 of 11) |##################        | Elapsed Time: 0:00:12 ETA:  0:00:04/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  81% (9 of 11) |#####################     | Elapsed Time: 0:00:13 ETA:  0:00:03/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  90% (10 of 11) |######################   | Elapsed Time: 0:00:15 ETA:  0:00:01/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# 100% (11 of 11) |#########################| Elapsed Time: 0:00:16 Time: 0:00:16
# <h3>Feature Splines</h3>
# <h3>Score model on test data</h3>
# <h4>RMSE from naive model that always predicts the previous week's rate</h4>
# RMSE: 0.00013
# <h4>RMSE from fitted model</h4>
# RMSE: 0.00012

# %% [markdown]
# ### All features

# %%
cols = [feature_cols[i] for i in range(n_feature_cols) 
        if re.search('JP_FX', feature_cols[i]) == None]
naive_rmse, fx_all_rmse = do_one_model('JPY', feature_col_names = ['JP_FX'] + cols, do_pca = True)
# Out:
# <h3>Prepare model data</h3>
# Time period: 2000-01-03 - 2012-12-05
# Scaled data shape: (4721, 141)
# Reframed data shape: (4708, 988)
# Cumulative variance explained by the first 93 components: 0.999
# <h4>Shape of train and test data after PCA</h4>
# Reduced data shape: (4708, 94)
# <h4>Shape of train and test data</h4>
# (3149, 93) (3149,) (1552, 93) (1552,)
# <h3>Fit model</h3>
# N/A% (0 of 11) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/pygam.py:597: RuntimeWarning: divide by zero encountered in log
#   return np.log(self.distribution.pdf(y=y, mu=mu, weights=weights)).sum()
#   9% (1 of 11) |##                        | Elapsed Time: 0:00:16 ETA:  0:02:49/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/pygam.py:597: RuntimeWarning: divide by zero encountered in log
#   return np.log(self.distribution.pdf(y=y, mu=mu, weights=weights)).sum()
#  18% (2 of 11) |####                      | Elapsed Time: 0:00:34 ETA:  0:02:35/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/pygam.py:597: RuntimeWarning: divide by zero encountered in log
#   return np.log(self.distribution.pdf(y=y, mu=mu, weights=weights)).sum()
#  27% (3 of 11) |#######                   | Elapsed Time: 0:00:51 ETA:  0:02:18/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/pygam.py:597: RuntimeWarning: divide by zero encountered in log
#   return np.log(self.distribution.pdf(y=y, mu=mu, weights=weights)).sum()
#  36% (4 of 11) |#########                 | Elapsed Time: 0:01:09 ETA:  0:02:01/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/pygam.py:597: RuntimeWarning: divide by zero encountered in log
#   return np.log(self.distribution.pdf(y=y, mu=mu, weights=weights)).sum()
#  45% (5 of 11) |###########               | Elapsed Time: 0:01:26 ETA:  0:01:43/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/pygam.py:597: RuntimeWarning: divide by zero encountered in log
#   return np.log(self.distribution.pdf(y=y, mu=mu, weights=weights)).sum()
#  54% (6 of 11) |##############            | Elapsed Time: 0:01:44 ETA:  0:01:26/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# /Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/pygam.py:597: RuntimeWarning: divide by zero encountered in log
#   return np.log(self.distribution.pdf(y=y, mu=mu, weights=weights)).sum()
#  63% (7 of 11) |################          | Elapsed Time: 0:02:01 ETA:  0:01:09/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  72% (8 of 11) |##################        | Elapsed Time: 0:02:19 ETA:  0:00:52/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  81% (9 of 11) |#####################     | Elapsed Time: 0:02:37 ETA:  0:00:35/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  90% (10 of 11) |######################   | Elapsed Time: 0:02:55 ETA:  0:00:17/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# 100% (11 of 11) |#########################| Elapsed Time: 0:03:13 Time: 0:03:13
# <h3>Score model on test data</h3>
# <h4>RMSE from naive model that always predicts the previous week's rate</h4>
# RMSE: 0.00015
# <h4>RMSE from fitted model</h4>
# RMSE: 0.0001

# %%
all_results = accum_results(all_results, 'JPY', naive_rmse, fx_rmse, fx_features_rmse, fx_all_rmse)

# %% [markdown]
# ## Switzerland

# %% [markdown]
# ### FX rates only

# %%
naive_rmse, fx_rmse = do_one_model('CHF', feature_col_names = ['CH_FX'], verbose = 0)
# Out:
# <h3>Prepare model data</h3>
# Time period: 2000-01-03 - 2017-12-09
# <h4>Features in Model</h4>
# CH_FX
#
# Scaled data shape: (6551, 1)
# Reframed data shape: (6538, 8)
# <h3>Fit model</h3>
# N/A% (0 of 11) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#   9% (1 of 11) |##                        | Elapsed Time: 0:00:00 ETA:  0:00:02/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  18% (2 of 11) |####                      | Elapsed Time: 0:00:00 ETA:  0:00:01/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  27% (3 of 11) |#######                   | Elapsed Time: 0:00:00 ETA:  0:00:01/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  36% (4 of 11) |#########                 | Elapsed Time: 0:00:00 ETA:  0:00:01/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  45% (5 of 11) |###########               | Elapsed Time: 0:00:01 ETA:  0:00:01/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  54% (6 of 11) |##############            | Elapsed Time: 0:00:01 ETA:  0:00:01/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  63% (7 of 11) |################          | Elapsed Time: 0:00:01 ETA:  0:00:00/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  72% (8 of 11) |##################        | Elapsed Time: 0:00:01 ETA:  0:00:00/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  81% (9 of 11) |#####################     | Elapsed Time: 0:00:01 ETA:  0:00:00/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  90% (10 of 11) |######################   | Elapsed Time: 0:00:02 ETA:  0:00:00/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# 100% (11 of 11) |#########################| Elapsed Time: 0:00:02 Time: 0:00:02
# <h3>Score model on test data</h3>
# <h4>RMSE from naive model that always predicts the previous week's rate</h4>
# RMSE: 0.01735
# <h4>RMSE from fitted model</h4>
# RMSE: 0.01702

# %% [markdown]
# ### FX rates and other features

# %%
naive_rmse, fx_features_rmse = do_one_model('CHF', feature_col_names = \
    ['CH_FX', 'CH_INT_TB', 'CH_GDP', 'CH_CPI', 'CH_UR'])
# Out:
# <h3>Prepare model data</h3>
# Time period: 2000-01-03 - 2017-12-09
# <h4>Features in Model</h4>
# CH_FX, CH_INT_TB, CH_GDP, CH_CPI, CH_UR
#
# Scaled data shape: (6551, 5)
# Reframed data shape: (6538, 36)
# <h4>First few rows of supervised data</h4>
# <p>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>CH_FX(t-7)</th>
#       <th>CH_INT_TB(t-7)</th>
#       <th>CH_GDP(t-7)</th>
#       <th>CH_CPI(t-7)</th>
#       <th>CH_UR(t-7)</th>
#       <th>CH_FX(t-6)</th>
#       <th>CH_INT_TB(t-6)</th>
#       <th>CH_GDP(t-6)</th>
#       <th>CH_CPI(t-6)</th>
#       <th>CH_UR(t-6)</th>
#       <th>CH_FX(t-5)</th>
#       <th>CH_INT_TB(t-5)</th>
#       <th>CH_GDP(t-5)</th>
#       <th>CH_CPI(t-5)</th>
#       <th>CH_UR(t-5)</th>
#       <th>CH_FX(t-4)</th>
#       <th>CH_INT_TB(t-4)</th>
#       <th>CH_GDP(t-4)</th>
#       <th>CH_CPI(t-4)</th>
#       <th>CH_UR(t-4)</th>
#       <th>CH_FX(t-3)</th>
#       <th>CH_INT_TB(t-3)</th>
#       <th>CH_GDP(t-3)</th>
#       <th>CH_CPI(t-3)</th>
#       <th>CH_UR(t-3)</th>
#       <th>CH_FX(t-2)</th>
#       <th>CH_INT_TB(t-2)</th>
#       <th>CH_GDP(t-2)</th>
#       <th>CH_CPI(t-2)</th>
#       <th>CH_UR(t-2)</th>
#       <th>CH_FX(t-1)</th>
#       <th>CH_INT_TB(t-1)</th>
#       <th>CH_GDP(t-1)</th>
#       <th>CH_CPI(t-1)</th>
#       <th>CH_UR(t-1)</th>
#       <th>CH_FX(t+6)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0

# <h3>Fit model</h3>
# N/A% (0 of 11) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#   9% (1 of 11) |##                        | Elapsed Time: 0:00:00 ETA:  0:00:02/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  18% (2 of 11) |####                      | Elapsed Time: 0:00:00 ETA:  0:00:01/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  27% (3 of 11) |#######                   | Elapsed Time: 0:00:00 ETA:  0:00:01/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  36% (4 of 11) |#########                 | Elapsed Time: 0:00:00 ETA:  0:00:01/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  45% (5 of 11) |###########               | Elapsed Time: 0:00:01 ETA:  0:00:01/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  54% (6 of 11) |##############            | Elapsed Time: 0:00:01 ETA:  0:00:01/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  63% (7 of 11) |################          | Elapsed Time: 0:00:01 ETA:  0:00:00/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  72% (8 of 11) |##################        | Elapsed Time: 0:00:01 ETA:  0:00:00/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  81% (9 of 11) |#####################     | Elapsed Time: 0:00:01 ETA:  0:00:00/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
#  90% (10 of 11) |######################   | Elapsed Time: 0:00:02 ETA:  0:00:00/Users/davidmodjeska/anaconda/lib/python3.6/site-packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# 100% (11 of 11) |#########################| Elapsed Time: 0:00:02 Time: 0:00:02
# <h3>Score model on test data</h3>
# <h4>RMSE from naive model that always predicts the previous week's rate</h4>
# RMSE: 0.02068
# <h4>RMSE from fitted model</h4>
# RMSE: 0.02058

# %% [markdown]
# ### FX rates and other features

# %%
naive_rmse, fx_features_rmse = do_one_model('GBP', feature_col_names = ['UK_FX', 'UK_GDP', 'US_INT_TB'])
# Out:
# <h3>Prepare model data</h3>
# Time period: 2000-01-03 - 2017-12-09
# <h4>Features in Model</h4>
# UK_FX, UK_GDP, US_INT_TB
#
# Scaled data shape: (6551, 3)
# Reframed data shape: (6538, 22)
# <h4>First few rows of supervised data</h4>
# <p>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>UK_FX(t-7)</th>
#       <th>UK_GDP(t-7)</th>
#       <th>US_INT_TB(t-7)</th>
#       <th>UK_FX(t-6)</th>
#       <th>UK_GDP(t-6)</th>
#       <th>US_INT_TB(t-6)</th>
#       <th>UK_FX(t-5)</th>
#       <th>UK_GDP(t-5)</th>
#       <th>US_INT_TB(t-5)</th>
#       <th>UK_FX(t-4)</th>
#       <th>UK_GDP(t-4)</th>
#       <th>US_INT_TB(t-4)</th>
#       <th>UK_FX(t-3)</th>
#       <th>UK_GDP(t-3)</th>
#       <th>US_INT_TB(t-3)</th>
#       <th>UK_FX(t-2)</th>
#       <th>UK_GDP(t-2)</th>
#       <th>US_INT_TB(t-2)</th>
#       <th>UK_FX(t-1)</th>
#       <th>UK_GDP(t-1)</th>
#       <th>US_INT_TB(t-1)</th>
#       <th>UK_FX(t+6)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.462052</td>
#       <td>0.850790</td>
#       <td>0.864422</td>
#       <td>0.473181</td>
#       <td>0.850158</td>
#       <td>0.865626</td>
#       <td>0.478188</td>
#       <td>0.849526</td>
#       <td>0.866831</td>
#       <td>0.484865</td>
#       <td>0.848894</td>
#       <td>0.868035</td>
#       <td>0.474738</td>
#       <td>0.848261</td>
#       <td>0.869240</td>
#       <td>0.474368</td>
#       <td>0.847629</td>
#       <td>0.870444</td>
#       <td>0.473997</td>
#       <td>0.846997</td>
#       <td>0.871649</td>
#       <td>0.472290</td>
#     </tr>
#     <tr>
#       <td>0.473181</td>
#       <td>0.850158</td>
#       <td>0.865626</td>
#       <td>0.478188</td>
#       <td>0.849526</td>
#       <td>0.866831</td>
#       <td>0.484865</td>
#       <td>0.848894</td>
#       <td>0.868035</td>
#       <td>0.474738</td>
#       <td>0.848261</td>
#       <td>0.869240</td>
#       <td>0.474368</td>
#       <td>0.847629</td>
#       <td>0.870444</td>
#       <td>0.473997</td>
#       <td>0.846997</td>
#       <td>0.871649</td>
#       <td>0.473626</td>
#       <td>0.846365</td>
#       <td>0.872853</td>
#       <td>0.472791</td>
#     </tr>
#     <tr>
#       <td>0.478188</td>
#       <td>0.849526</td>
#       <td>0.866831</td>
#       <td>0.484865</td>
#       <td>0.848894</td>
#       <td>0.868035</td>
#       <td>0.474738</td>
#       <td>0.848261</td>
#       <td>0.869240</td>
#       <td>0.474368</td>
#       <td>0.847629</td>
#       <td>0.870444</td>
#       <td>0.473997</td>
#       <td>0.846997</td>
#       <td>0.871649</td>
#       <td>0.473626</td>
#       <td>0.846365</td>
#       <td>0.872853</td>
#       <td>0.485422</td>
#       <td>0.845732</td>
#       <td>0.874057</td>
#       <td>0.474293</td>
#     </tr>
packages/pygam/utils.py:69: UserWarning: Could not import Scikit-Sparse or Suite-Sparse.
# This will slow down optimization for models with monotonicity/convexity penalties and many splines.
# See installation instructions for installing Scikit-Sparse and Suite-Sparse via Conda.
#   warnings.warn(msg)
# 100% (11 of 11) |#########################| Elapsed Time: 0:03:13 Time: 0:03:13
# <h3>Score model on test data</h3>
# <h4>RMSE from naive model that always predicts the previous week's rate</h4>
# RMSE: 0.0229
# <h4>RMSE from fitted model</h4>
# RMSE: 0.01342

# %%
all_results = accum_results(all_results, 'GBP', naive_rmse, fx_rmse, fx_features_rmse, fx_all_rmse)

# %% [markdown]
# # Summary of results

# %% [markdown]
# #### Test RMSE for all FX rates (relative to USD)

# %%
all_results = all_results[['Currency', 'Naive', 'FX Only', 'FX + Features', 'All Features']]
all_results.to_csv('RMSE_GAM_7.csv', index = False)

pd.options.display.float_format = '{:,.5f}'.format
my_linespace()
my_display_df(all_results)
# Out:
# <p>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Currency</th>
#       <th>Naive</th>
#       <th>FX Only</th>
#       <th>FX + Features</th>
#       <th>All Features</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>AUD</td>
#       <td>0.01553</td>
#       <td>0.01373</td>
#       <td>0.01220</td>
#       <td>0.00920</td>
#     </tr>
#     <tr>
#       <td>CAD</td>
#       <td>0.01205</td>
#       <td>0.01060</td>
#       <td>0.00935</td>
#       <td>0.00721</td>
#     </tr>
#     <tr>
#       <td>EUR</td>
#       <td>0.01811</td>
#       <td>0.01680</td>
#       <td>0.01595</td>
#       <td>0.01160</td>
#     </tr>
#     <tr>
#       <td>JPY</td>
#       <td>0.00015</td>
#       <td>0.00013</td>
#       <td>0.00012</td>
#       <td>0.00010</td>
#     </tr>
#     <tr>
#       <td>CHF</td>
#       <td>0.01652</td>
#       <td>0.01702</td>
#       <td>0.01488</td>
#       <td>0.00980</td>
#     </tr>
#     <tr>
#       <td>GBP</td>
#       <td>0.02290</td>
#       <td>0.02058</td>
#       <td>0.01891</td>
#       <td>0.01342</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Test RMSE as a share of naive RMSE for all FX rates (relative to USD)

# %%
pd.options.display.float_format = '{:,.2f}'.format

all_results_2 = all_results.drop('Naive', axis = 1)
all_results_2['FX Only'] = np.round(all_results['FX Only'] / all_results['Naive'], 3)
all_results_2['FX + Features'] = np.round(all_results['FX + Features'] / all_results['Naive'], 3)
all_results_2['All Features'] = np.round(all_results['All Features'] / all_results['Naive'], 3)
all_results_2 = all_results_2[['Currency', 'FX Only', 'FX + Features', 'All Features']]
all_results_2.to_csv('Test_Naive_GAM_7.csv', index = False)

my_linespace()
my_display_df(all_results_2)
# Out:
# <p>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Currency</th>
#       <th>FX Only</th>
#       <th>FX + Features</th>
#       <th>All Features</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>AUD</td>
#       <td>0.89</td>
#       <td>0.79</td>
#       <td>0.59</td>
#     </tr>
#     <tr>
#       <td>CAD</td>
#       <td>0.88</td>
#       <td>0.78</td>
#       <td>0.60</td>
#     </tr>
#     <tr>
#       <td>EUR</td>
#       <td>0.93</td>
#       <td>0.88</td>
#       <td>0.64</td>
#     </tr>
#     <tr>
#       <td>JPY</td>
#       <td>0.90</td>
#       <td>0.84</td>
#       <td>0.70</td>
#     </tr>
#     <tr>
#       <td>CHF</td>
#       <td>1.03</td>
#       <td>0.90</td>
#       <td>0.59</td>
#     </tr>
#     <tr>
#       <td>GBP</td>
#       <td>0.90</td>
#       <td>0.83</td>
#       <td>0.59</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Visualize test RMSE as a share of naive RMSE

# %%
n_items = all_results.shape[0]

print()
fig, ax = plt.subplots(figsize = (8, 4))

ax.axhline(y = 1.0, color = '0.6', linestyle = '--', label = 'Naive')

ax.plot(range(n_items), all_results_2['FX Only'], label = 'FX Only')
ax.plot(range(n_items), all_results_2['FX + Features'], label = 'FX + Features')
ax.plot(range(n_items), all_results_2['All Features'], label = 'All Features')

ax.set_ylim((0., 1.2))
ax.set_xticks(range(n_items))
ax.set_xticklabels(all_results_2['Currency'])

ax.set_xlabel('Currency')
ax.set_ylabel('Test/naive RMSE')
ax.set_title('Test/naive RMSE by currency')

plt.legend(loc = 'lower right')
plt.show()
